# %%
# %matplotlib nbagg
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = 7,5

# %%
x = np.array(["13-17", "18-24", "25-34", "35-44", "45-54", "55-64", "65+"])
y = np.array([1, 2, 3, 4, 5, 6, 7])

fig, ax = plt.subplots()

ax.bar(x, y)

ax.set_title("Por no gráfico")
ax.set_xlabel("Idade")
ax.set_ylabel("Memes por segundo")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="700">
